# %%
# %store -r QA1_Data

# %%
# %store -r QA2_Data

# %%
# %store -r QA3_Data

# %%
len(QA1_Data)
# Out:
# 49

# %%
len(QA2_Data)
# Out:
# 49

# %%
len(QA3_Data)
# Out:
# 49

# %%
def termFrequency(data, section):
    if(section == 'introduction'):
        keywords = ['aim', 'objective', 'motivation', 'objectives', 'goal']
    elif(section == 'methods'):
        keywords = ['methods', 'methodology', 'research methodology', 'approach', 'techniques']
    elif(section == 'conclusion'):
        keywords = ['conclusions', 'discussions', 'justifications', 'summary', ]
    count = 0
    for i in range(len(data)):
        doc_wordList = []
        wordfreq  = []
        selected_words = []
        ignore_words = []     
        count = count + 1
        doc = data[i]
        for line in doc:
            #print(line)
            wordlist = line.split()
            for w in wordlist:
                if w in keywords:
                    wordfreq.append(wordlist.count(w)) #frequency of each word
                    selected_words.append(w)
                else:
                    ignore_words.append(w)     
        if(len(selected_words) > 2 ):
            #print(count)
            print("The tool totally recommends document " , count )  
            print(selected_words)
        elif(len(selected_words) >= 1) and (len(selected_words) <= 2):
            print("The tool partially recommends document", count)
            print(selected_words)
        else:
            print("The tool does not recommend document " , count)
            print(selected_words)

# %%
section = 'introduction'
result = termFrequency(QA1_Data, section)
# Out:
# The tool totally recommends document  1
# ['objective', 'objective', 'objective', 'objective', 'aim']
# The tool totally recommends document  2
# ['aim', 'aim', 'aim', 'aim', 'aim']
# The tool totally recommends document  3
# ['aim', 'objective', 'objective', 'objective', 'objective']
# The tool partially recommends document 4
# ['objective', 'objective']
# The tool totally recommends document  5
# ['aim', 'aim', 'objective', 'objective', 'objective']
# The tool does not recommend document  6
# []
# The tool totally recommends document  7
# ['aim', 'aim', 'objective', 'objective', 'objective']
# The tool totally recommends document  8
# ['aim', 'aim', 'aim', 'objective', 'objective', 'objective', 'objective']
# The tool totally recommends document  9
# ['aim', 'aim', 'aim', 'aim', 'objective']
# The tool totally recommends document  10
# ['objective', 'objective', 'objective', 'objective']
# The tool does not recommend document  11
# []
# The tool totally recommends document  12
# ['aim', 'aim', 'aim', 'objective', 'objective']
# The tool totally recommends document  13
# ['aim', 'aim', 'aim', 'aim', 'aim']
# The tool totally recommends document  14
# ['aim', 'aim', 'objective', 'objective', 'objective']
# The tool partially recommends document 15
# ['aim', 'aim']
# The tool totally recommends document  16
# ['objective', 'objective', 'objective', 'objective', 'aim']
# The tool totally recommends document  17
# ['aim', 'aim', 'aim', 'aim', 'aim']
# The tool partially recommends document 18
# ['objective']
# The tool totally recommends document  19
# ['objective', 'objective', 'objective', 'objective', 'objective']
# The tool does not recommend document  20
# []
# The tool does not recommend document  21
# []
# The tool totally recommends document  22
# ['aim', 'aim', 'aim', 'aim', 'aim']
# The tool totally recommends document  23
# ['objective', 'objective', 'objective', 'objective', 'objective']
# The tool totally recommends document  24
# ['objective', 'objective', 'objective', 'objective', 'aim']
# The tool totally recommends document  25
# ['objective', 'objective', 'objective', 'objective', 'objective']
# The tool partially recommends document 26
# ['objective']
# The tool partially recommends document 27
# ['objectives']
# The tool partially recommends document 28
# ['aim', 'aim']
# The tool totally recommends document  29
# ['objective', 'objective', 'objective', 'objective', 'objective']
# The tool partially recommends document 30
# ['aim', 'aim']
# The tool totally recommends document  31
# ['aim', 'aim', 'aim', 'aim', 'aim']
# The tool does not recommend document  32
# []
# The tool does not recommend document  33
# []
# The tool totally recommends document  34
# ['objective', 'objective', 'objective', 'objective', 'objective']
# The tool totally recommends document  35
# ['aim', 'aim', 'objective', 'objective', 'objective']
# The tool totally recommends document  36
# ['objective', 'objective', 'objective', 'objective']
# The tool totally recommends document  37
# ['objective', 'objective', 'aim', 'aim', 'aim']
# The tool totally recommends document  38
# ['objective', 'objective', 'objective', 'objective', 'objective', 'objectives']
# The tool totally recommends document  39
# ['aim', 'aim', 'objective', 'objective', 'objective']
# The tool does not recommend document  40
# []
# The tool totally recommends document  41
# ['objective', 'objective', 'objective', 'objective', 'objective']
# The tool totally recommends document  42
# ['aim', 'objective', 'objective']
# The tool totally recommends document  43
# ['aim', 'aim', 'aim', 'objective']
# The tool partially recommends document 44
# ['objective', 'objective']
# The tool totally recommends document  45
# ['objective', 'objective', 'aim', 'aim', 'aim']
# The tool partially recommends document 46
# ['objective', 'objective']
# The tool totally recommends document  47
# ['aim', 'aim', 'objective', 'objective', 'objective']
# The tool does not recommend document  48
# []
# The tool does not recommend document  49
# []

# %%
section = 'methods'
result = termFrequency(QA2_Data, section)
# Out:
# The tool does not recommend document  1
# []
# The tool partially recommends document 2
# ['methodology', 'methodology']
# The tool does not recommend document  3
# []
# The tool does not recommend document  4
# []
# The tool partially recommends document 5
# ['approach', 'approach']
# The tool does not recommend document  6
# []
# The tool does not recommend document  7
# []
# The tool does not recommend document  8
# []
# The tool does not recommend document  9
# []
# The tool does not recommend document  10
# []
# The tool partially recommends document 11
# ['techniques']
# The tool totally recommends document  12
# ['approach', 'approach', 'approach']
# The tool totally recommends document  13
# ['methods', 'methods', 'methods']
# The tool does not recommend document  14
# []
# The tool partially recommends document 15
# ['methodology']
# The tool does not recommend document  16
# []
# The tool does not recommend document  17
# []
# The tool totally recommends document  18
# ['approach', 'methodology', 'approach']
# The tool does not recommend document  19
# []
# The tool totally recommends document  20
# ['methods', 'methods', 'methods']
# The tool does not recommend document  21
# []
# The tool partially recommends document 22
# ['approach']
# The tool totally recommends document  23
# ['methods', 'methods', 'methods', 'approach']
# The tool totally recommends document  24
# ['approach', 'approach', 'approach', 'approach']
# The tool does not recommend document  25
# []
# The tool does not recommend document  26
# []
# The tool partially recommends document 27
# ['approach']
# The tool partially recommends document 28
# ['methods']
# The tool does not recommend document  29
# []
# The tool does not recommend document  30
# []
# The tool does not recommend document  31
# []
# The tool partially recommends document 32
# ['approach']
# The tool does not recommend document  33
# []
# The tool does not recommend document  34
# []
# The tool does not recommend document  35
# []
# The tool totally recommends document  36
# ['techniques', 'techniques', 'techniques', 'techniques', 'techniques', 'approach']
# The tool does not recommend document  37
# []
# The tool partially recommends document 38
# ['methods', 'methods']
# The tool does not recommend document  39
# []
# The tool partially recommends document 40
# ['methods', 'methods']
# The tool does not recommend document  41
# []
# The tool totally recommends document  42
# ['approach', 'approach', 'approach', 'approach', 'techniques', 'methods']
# The tool does not recommend document  43
# []
# The tool does not recommend document  44
# []
# The tool does not recommend document  45
# []
# The tool does not recommend document  46
# []
# The tool does not recommend document  47
# []
# The tool does not recommend document  48
# []
# The tool does not recommend document  49
# []

# %%
section = 'conclusion'
result = termFrequency(QA3_Data, section)
# Out:
# The tool does not recommend document  1
# []
# The tool partially recommends document 2
# ['conclusions', 'conclusions']
# The tool partially recommends document 3
# ['conclusions']
# The tool does not recommend document  4
# []
# The tool does not recommend document  5
# []
# The tool does not recommend document  6
# []
# The tool totally recommends document  7
# ['conclusions', 'conclusions', 'discussions', 'conclusions', 'conclusions']
# The tool does not recommend document  8
# []
# The tool totally recommends document  9
# ['discussions', 'discussions', 'discussions', 'discussions']
# The tool does not recommend document  10
# []
# The tool does not recommend document  11
# []
# The tool totally recommends document  12
# ['conclusions', 'conclusions', 'discussions', 'discussions', 'discussions']
# The tool does not recommend document  13
# []
# The tool totally recommends document  14
# ['conclusions', 'conclusions', 'discussions', 'discussions', 'conclusions', 'conclusions', 'discussions', 'discussions']
# The tool does not recommend document  15
# []
# The tool partially recommends document 16
# ['conclusions']
# The tool partially recommends document 17
# ['discussions', 'discussions']
# The tool partially recommends document 18
# ['conclusions']
# The tool totally recommends document  19
# ['discussions', 'discussions', 'discussions', 'discussions', 'discussions']
# The tool does not recommend document  20
# []
# The tool does not recommend document  21
# []
# The tool totally recommends document  22
# ['conclusions', 'conclusions', 'conclusions', 'conclusions', 'conclusions', 'conclusions', 'conclusions']
# The tool totally recommends document  23
# ['discussions', 'discussions', 'discussions', 'discussions', 'discussions', 'discussions', 'conclusions', 'conclusions', 'conclusions', 'discussions']
# The tool does not recommend document  24
# []
# The tool does not recommend document  25
# []
# The tool does not recommend document  26
# []
# The tool totally recommends document  27
# ['conclusions', 'discussions', 'discussions']
# The tool partially recommends document 28
# ['discussions', 'discussions']
# The tool partially recommends document 29
# ['discussions']
# The tool does not recommend document  30
# []
# The tool totally recommends document  31
# ['discussions', 'discussions', 'discussions']
# The tool totally recommends document  32
# ['justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications', 'justifications']
# The tool does not recommend document  33
# []
# The tool partially recommends document 34
# ['conclusions']
# The tool does not recommend document  35
# []
# The tool does not recommend document  36
# []
# The tool does not recommend document  37
# []
# The tool partially recommends document 38
# ['conclusions']
# The tool totally recommends document  39
# ['conclusions', 'conclusions', 'conclusions', 'conclusions', 'conclusions']
# The tool does not recommend document  40
# []
# The tool totally recommends document  41
# ['conclusions', 'conclusions', 'conclusions', 'conclusions', 'conclusions', 'discussions', 'discussions', 'discussions', 'summary', 'conclusions', 'discussions', 'discussions']
# The tool totally recommends document  42
# ['conclusions', 'conclusions', 'conclusions']
# The tool does not recommend document  43
# []
# The tool does not recommend document  44
# []
# The tool does not recommend document  45
# []
# The tool partially recommends document 46
# ['conclusions', 'discussions']
# The tool totally recommends document  47
# ['conclusions', 'conclusions', 'conclusions', 'conclusions', 'conclusions', 'conclusions']
# The tool does not recommend document  48
# []
# The tool totally recommends document  49
# ['conclusions', 'conclusions', 'conclusions']
